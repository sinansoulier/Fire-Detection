# %% [markdown]
# # Fire detection - Yolo (You Only Look Once)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/fire_detection
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/fire_detection

# %% [markdown]
# ## Setup

# %%
# Clone the YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Install the required dependencies
# !pip install -r yolov5/requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 35.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !cp -rf data_subset/ yolov5/data_subset

# %% [markdown]
# ## Fine-tuning / Training

# %%
# !python yolov5/train.py --img 640 --batch 8 --epochs 10 --data data_subset/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-10-10 19:38:02.583170: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-10 19:38:02.620412: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-10 19:38:02.631054: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Test

# %%
# !python yolov5/val.py --data data_subset/data.yaml --weights yolov5/runs/train/exp4/weights/best.pt --img 640 --iou 0.65 --task test
# Out:
# val: data=data_subset/data.yaml, weights=['yolov5/runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-371-g6629839d Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/fire_detection/yolov5/data_subset/test/labels... 152 images, 0 backgrounds, 0 corrupt: 100% 152/152 [00:43<00:00,  3.47it/s]
# test: New cache created: /content/drive/MyDrive/fire_detection/yolov5/data_subset/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/5 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 2.100s exceeded
# ...

# %% [markdown]
# | Class | Images | Instances | P    | R    | mAP50 | mAP50-95 |
# |-------|--------|-----------|------|------|-------|----------|
# | all   | 152    | 153       | 0.301| 0.245| 0.219 | 0.0941   |
